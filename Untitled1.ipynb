# %%
import requests
from pprint import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from scipy.cluster.vq import whiten, kmeans2

# %%
def call_api(url, item):
    json = {}
    try:
        json = requests.get(url, headers = { 'X-Auth-Token': 'c52b7825851b4357af3e06c1888152f0' }).json()
        return json[item]
    except:
        print(json)
        return None

# %%
league_table = call_api('http://api.football-data.org/v1/soccerseasons/426/leagueTable', 'standing')

# %%
my_data = []
for team in league_table:
    my_data.append({'losses': team['losses'], 
                    'value': make_int(call_api(team['_links']['team']['href'], 'squadMarketValue'))})

# %%
def make_int(string):
    string = string.replace('€', '').strip().replace(',', '')
    return int(string)

# %%
def print_kmeans(data, n):
    data_frame = pd.DataFrame(data)
    whitened = whiten(data_frame.as_matrix())
    centroids, cluster_map = kmeans2(whitened, n)
    colors_map = {0: 'r', 1: 'g', 2: 'b', 3: 'y', 4: 'm'}
    colors = [colors_map[c] for c in cluster_map]
    teams_pd.plot.scatter(x='losses', y='value', c=colors)

# %%
print_kmeans(my_data, 3)

# %%
print_kmeans(my_data, 5)
